# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.5.3'

# %%
name_file = "Dane_ofert_wynajem_Rzeszow_Otodom_2024_08_31.csv"

# %%
df = pd.read_csv(name_file, index_col=0)
df
# Out:
#                                                  Title  \
# Nr
# 1        Dwupokojowe,54m2,Rzeszow,Kopernika,rej.Rynku,
# 2    Wyjatkowe mieszkanie 2 pok. SKYRES 16p. z wido...
# 3             Kawalerka z balkonem Rzeszow Architektow
# 4                    Wygodna kawalerka ul. Podwislocze
# 5            Mieszkanie 48 m2 z ogrodkiem bezposrednio
# ..                                                 ...
# 320        Przytulne mieszkanie - Pobitno Rzeszow 70m2
# 321       EXCLUSIVE Apartament on KRAKOVSKA in Rzeszow
# 322         Wynajem, Kwiatkowskiego Tarasy nad Zalewem
# 323   wynajme mieszkanie Baranowka ladne/wysoka jakosc
# 324  Apartament do wynajecia przy zalewie w Rzeszowie!
#
#                             Street          District     City   Voivodeship  \
# Nr
# 1           ul. Mikolaja Kopernika       Srodmiescie  Rzeszow  podkarpackie
# 2                     ul. Lubelska        1000-Lecia  Rzeszow  podkarpackie
# 3                    ul. Podgorska  Zawiszy Czarnego  Rzeszow  podkarpackie
# 4                  ul. Podwislocze       Nowe Miasto  Rzeszow  podkarpackie
# 5      ul. kard. Karola Wojtyly 70       Srodmiescie  Rzeszow  podkarpackie
# ..                             ...               ...      ...           ...
# 320                 ul. Kurpiowska           Pobitno  Rzeszow  podkarpackie
# 321               ul. Krakowska 31      Przybyszowka  Rzeszow  podkarpackie
# 322  ul. Eugeniusza Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
# 323        ul. Wladyslawa Raginisa         Baranowka  Rzeszow  podkarpackie
# 324  ul. Eugeniusza Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
#
#                                                   Link  Price [PLN]  \
# Nr
# 1    https://www.otodom.pl/pl/oferta/dwupokojowe-54...         2400
# 2    https://www.otodom.pl/pl/oferta/wyjatkowe-mies...         2500
# 3    https://www.otodom.pl/pl/oferta/kawalerka-z-ba...         1600
# 4    https://www.otodom.pl/pl/oferta/wygodna-kawale...          800
# 5    https://www.otodom.pl/pl/oferta/mieszkanie-48-...         2500
# ..                                                 ...          ...
# 320  https://www.otodom.pl/pl/oferta/przytulne-mies...         2400
# 321  https://www.otodom.pl/pl/oferta/exclusive-apar...         2700
# 322  https://www.otodom.pl/pl/oferta/wynajem-kwiatk...         2700
# 323  https://www.otodom.pl/pl/oferta/wynajme-mieszk...         2500
# 324  https://www.otodom.pl/pl/oferta/apartament-do-...         3000
#
#      Number_of_room  Surface [m2]  Rent [PLN/month]  Offer_type  \
# Nr
# 1                 2          54.0             720.0         NaN
# 2                 2          37.0             225.0         NaN
# 3                 1          23.0             422.0         NaN
# 4                 1          45.0               NaN         NaN
# 5                 2          48.0             450.0         NaN
# ..              ...           ...               ...         ...
# 320               3          70.0             800.0         NaN
# 321               2          40.0            1000.0         NaN
# 322               2          52.0             800.0         NaN
# 323               2          49.0             700.0         NaN
# 324               2          45.5             550.0         NaN
#
#                     Time
# Nr
# 1    2024-08-31 21:54:46
# 2    2024-08-31 21:54:47
# 3    2024-08-31 21:54:47
# 4    2024-08-31 21:54:47
# 5    2024-08-31 21:54:48
# ..                   ...
# 320  2024-08-31 21:56:24
# 321  2024-08-31 21:56:25
# 322  2024-08-31 21:56:25
# 323  2024-08-31 21:56:26
# 324  2024-08-31 21:56:26
#
# [324 rows x 12 columns]

# %%
df.shape
# Out:
# (324, 12)

# %%
df.columns = [col.lower() for col in df.columns]
df = df.rename(columns={'price [pln]': 'price', 'surface [m2]': 'surface ', 'rent [pln/month]': 'rent'})
df.head()
# Out:
#                                                 title  \
# Nr
# 1       Dwupokojowe,54m2,Rzeszow,Kopernika,rej.Rynku,
# 2   Wyjatkowe mieszkanie 2 pok. SKYRES 16p. z wido...
# 3            Kawalerka z balkonem Rzeszow Architektow
# 4                   Wygodna kawalerka ul. Podwislocze
# 5           Mieszkanie 48 m2 z ogrodkiem bezposrednio
#
#                          street          district     city   voivodeship  \
# Nr
# 1        ul. Mikolaja Kopernika       Srodmiescie  Rzeszow  podkarpackie
# 2                  ul. Lubelska        1000-Lecia  Rzeszow  podkarpackie
# 3                 ul. Podgorska  Zawiszy Czarnego  Rzeszow  podkarpackie
# 4               ul. Podwislocze       Nowe Miasto  Rzeszow  podkarpackie
# 5   ul. kard. Karola Wojtyly 70       Srodmiescie  Rzeszow  podkarpackie
#
#                                                  link  price  number_of_room  \
# Nr
# 1   https://www.otodom.pl/pl/oferta/dwupokojowe-54...   2400               2
# 2   https://www.otodom.pl/pl/oferta/wyjatkowe-mies...   2500               2
# 3   https://www.otodom.pl/pl/oferta/kawalerka-z-ba...   1600               1
# 4   https://www.otodom.pl/pl/oferta/wygodna-kawale...    800               1
# 5   https://www.otodom.pl/pl/oferta/mieszkanie-48-...   2500               2
#
#     surface    rent  offer_type                 time
# Nr
# 1       54.0  720.0         NaN  2024-08-31 21:54:46
# 2       37.0  225.0         NaN  2024-08-31 21:54:47
# 3       23.0  422.0         NaN  2024-08-31 21:54:47
# 4       45.0    NaN         NaN  2024-08-31 21:54:47
# 5       48.0  450.0         NaN  2024-08-31 21:54:48

# %%
df['rent'].replace('Unknow', np.nan, inplace=True)
df['rent'].replace('', np.nan, inplace=True)
df['district'] = df['district'].str.replace(' ', "_", regex=False)
# df['offer_type'] = df['offer_type'].str.replace(' ', "_", regex=False)
df['street'] = df['street'].str.replace('ul. ', "", regex=False)
df['street'] = df['street'].str.replace('al. ', "", regex=False)
df['street'] = df['street'].str.replace(' ', "_", regex=False)

# %%
df
# Out:
#                                                  title  \
# Nr
# 1        Dwupokojowe,54m2,Rzeszow,Kopernika,rej.Rynku,
# 2    Wyjatkowe mieszkanie 2 pok. SKYRES 16p. z wido...
# 3             Kawalerka z balkonem Rzeszow Architektow
# 4                    Wygodna kawalerka ul. Podwislocze
# 5            Mieszkanie 48 m2 z ogrodkiem bezposrednio
# ..                                                 ...
# 320        Przytulne mieszkanie - Pobitno Rzeszow 70m2
# 321       EXCLUSIVE Apartament on KRAKOVSKA in Rzeszow
# 322         Wynajem, Kwiatkowskiego Tarasy nad Zalewem
# 323   wynajme mieszkanie Baranowka ladne/wysoka jakosc
# 324  Apartament do wynajecia przy zalewie w Rzeszowie!
#
#                         street          district     city   voivodeship  \
# Nr
# 1           Mikolaja_Kopernika       Srodmiescie  Rzeszow  podkarpackie
# 2                     Lubelska        1000-Lecia  Rzeszow  podkarpackie
# 3                    Podgorska  Zawiszy_Czarnego  Rzeszow  podkarpackie
# 4                  Podwislocze       Nowe_Miasto  Rzeszow  podkarpackie
# 5      kard._Karola_Wojtyly_70       Srodmiescie  Rzeszow  podkarpackie
# ..                         ...               ...      ...           ...
# 320                 Kurpiowska           Pobitno  Rzeszow  podkarpackie
# 321               Krakowska_31      Przybyszowka  Rzeszow  podkarpackie
# 322  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
# 323        Wladyslawa_Raginisa         Baranowka  Rzeszow  podkarpackie
# 324  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
#
#                                                   link  price  number_of_room  \
# Nr
# 1    https://www.otodom.pl/pl/oferta/dwupokojowe-54...   2400               2
# 2    https://www.otodom.pl/pl/oferta/wyjatkowe-mies...   2500               2
# 3    https://www.otodom.pl/pl/oferta/kawalerka-z-ba...   1600               1
# 4    https://www.otodom.pl/pl/oferta/wygodna-kawale...    800               1
# 5    https://www.otodom.pl/pl/oferta/mieszkanie-48-...   2500               2
# ..                                                 ...    ...             ...
# 320  https://www.otodom.pl/pl/oferta/przytulne-mies...   2400               3
# 321  https://www.otodom.pl/pl/oferta/exclusive-apar...   2700               2
# 322  https://www.otodom.pl/pl/oferta/wynajem-kwiatk...   2700               2
# 323  https://www.otodom.pl/pl/oferta/wynajme-mieszk...   2500               2
# 324  https://www.otodom.pl/pl/oferta/apartament-do-...   3000               2
#
#      surface     rent  offer_type                 time
# Nr
# 1        54.0   720.0         NaN  2024-08-31 21:54:46
# 2        37.0   225.0         NaN  2024-08-31 21:54:47
# 3        23.0   422.0         NaN  2024-08-31 21:54:47
# 4        45.0     NaN         NaN  2024-08-31 21:54:47
# 5        48.0   450.0         NaN  2024-08-31 21:54:48
# ..        ...     ...         ...                  ...
# 320      70.0   800.0         NaN  2024-08-31 21:56:24
# 321      40.0  1000.0         NaN  2024-08-31 21:56:25
# 322      52.0   800.0         NaN  2024-08-31 21:56:25
# 323      49.0   700.0         NaN  2024-08-31 21:56:26
# 324      45.5   550.0         NaN  2024-08-31 21:56:26
#
# [324 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324 entries, 1 to 324
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           324 non-null    object
#  1   street          241 non-null    object
#  2   district        324 non-null    object
#  3   city            324 non-null    object
#  4   voivodeship     324 non-null    object
#  5   link            324 non-null    object
#  6   price           324 non-null    int64
#  7   number_of_room  324 non-null    int64
#  8   surface         324 non-null    float64
#  9   rent            258 non-null    float64
#  10  offer_type      0 non-null      float64
#  11  time            324 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 32.9+ KB

# %%
df.describe().T
# Out:
#                 count         mean         std     min     25%     50%  \
# price           324.0  2580.277778  842.311200  800.00  2075.0  2500.0
# number_of_room  324.0     2.345679    0.812602    1.00     2.0     2.0
# surface         324.0    51.171883   16.854751   17.17    42.0    50.0
# rent            258.0   645.155039  242.962438    1.00   500.0   700.0
# offer_type        0.0          NaN         NaN     NaN     NaN     NaN
#
#                    75%     max
# price           2900.0  7500.0
# number_of_room     3.0     5.0
# surface           56.0   110.0
# rent             800.0  1300.0
# offer_type         NaN     NaN

# %%
df.price.median()
# Out:
# 2500.0

# %%
df.to_csv(name_file)

# %%
df = pd.read_csv(name_file)

# %%
df['rent'].replace(' ', '', inplace=True)

# %%
df['rent'].replace(',', '.', inplace=True)
df.tail(20)
# Out:
#       Nr                                              title  \
# 304  305              Trzypokojowe mieszkanie ul. Strazacka
# 305  306         3 pokojowe mieszkanie, Malopolska /Rzeszow
# 306  307              Mieszkanie do wynajecia Zig-Zak House
# 307  308   Super mieszkanie z widokiem na Wislok na Kopisto
# 308  309    Mieszkanie w bardzo dobrej lokalizacji - Ulanow
# 309  310         Wieniawskiego 38m+taras- 2600 zl z garazem
# 310  311  na wynajem nowe 50m2 Paderewskiego Park | Mp i Kl
# 311  312               Mieszkanie 2 pokojowe CAPITAL TOWERS
# 312  313                      Mieszkanie do wynajecia 57 m2
# 313  314     Ciche 3-pokojowe mieszkanie w centrum Rzeszowa
# 314  315  Piekne mieszkanie 48m2 Krakowska BRYKSY Bezpos...
# 315  316  Dwupoziomowe Mieszkanie Wynajem 110M2, Projektant
# 316  317  Architektow, 2 pokoje, 7 pietro, taras, atrakc...
# 317  318  Kawalerki na wynajem, blisko Uniwersytetu! Wie...
# 318  319  Atrakcyjne mieszkanie, ul Blogoslawionej Karoliny
# 319  320        Przytulne mieszkanie - Pobitno Rzeszow 70m2
# 320  321       EXCLUSIVE Apartament on KRAKOVSKA in Rzeszow
# 321  322         Wynajem, Kwiatkowskiego Tarasy nad Zalewem
# 322  323   wynajme mieszkanie Baranowka ladne/wysoka jakosc
# 323  324  Apartament do wynajecia przy zalewie w Rzeszowie!
#
#                         street            district     city   voivodeship  \
# 304                  Strazacka         Drabinianka  Rzeszow  podkarpackie
# 305                 Malopolska             Pobitno  Rzeszow  podkarpackie
# 306  Eugeniusza_Kwiatkowskiego         Drabinianka  Rzeszow  podkarpackie
# 307       mjr._Waclawa_Kopisto         Nowe_Miasto  Rzeszow  podkarpackie
# 308                        NaN           Mieszka_I  Rzeszow  podkarpackie
# 309                        NaN             Zalesie  Rzeszow  podkarpackie
# 310     Ignacego_Paderewskiego             Slocina  Rzeszow  podkarpackie
# 311                Podwislocze           Mieszka_I  Rzeszow  podkarpackie
# 312                        NaN        Staromiescie  Rzeszow  podkarpackie
# 313                        NaN         Srodmiescie  Rzeszow  podkarpackie
# 314                        NaN  Krakowska-Poludnie  Rzeszow  podkarpackie
# 315                        NaN   Franciszka_Kotuli  Rzeszow  podkarpackie
# 316                Architektow    Zawiszy_Czarnego  Rzeszow  podkarpackie
# 317      Henryka_Wieniawskiego             Zalesie  Rzeszow  podkarpackie
# 318               bl._Karoliny   Franciszka_Kotuli  Rzeszow  podkarpackie
# 319                 Kurpiowska             Pobitno  Rzeszow  podkarpackie
# 320               Krakowska_31        Przybyszowka  Rzeszow  podkarpackie
# 321  Eugeniusza_Kwiatkowskiego         Drabinianka  Rzeszow  podkarpackie
# 322        Wladyslawa_Raginisa           Baranowka  Rzeszow  podkarpackie
# 323  Eugeniusza_Kwiatkowskiego         Drabinianka  Rzeszow  podkarpackie
#
#                                                   link  price  number_of_room  \
# 304  https://www.otodom.pl/pl/oferta/trzypokojowe-m...   2950               3
# 305  https://www.otodom.pl/pl/oferta/3-pokojowe-mie...   2850               3
# 306  https://www.otodom.pl/pl/oferta/mieszkanie-do-...   1600               2
# 307  https://www.otodom.pl/pl/oferta/super-mieszkan...   3100               2
# 308  https://www.otodom.pl/pl/oferta/mieszkanie-w-b...   3300               3
# 309  https://www.otodom.pl/pl/oferta/wieniawskiego-...   2600               2
# 310  https://www.otodom.pl/pl/oferta/na-wynajem-now...   2950               2
# 311  https://www.otodom.pl/pl/oferta/mieszkanie-2-p...   2500               2
# 312  https://www.otodom.pl/pl/oferta/mieszkanie-do-...   2000               2
# 313  https://www.otodom.pl/pl/oferta/ciche-3-pokojo...   2800               3
# 314  https://www.otodom.pl/pl/oferta/piekne-mieszka...   2300               3
# 315  https://www.otodom.pl/pl/oferta/dwupoziomowe-m...   6000               5
# 316  https://www.otodom.pl/pl/oferta/architektow-2-...   1870               2
# 317  https://www.otodom.pl/pl/oferta/kawalerki-na-w...   1800               1
# 318  https://www.otodom.pl/pl/oferta/atrakcyjne-mie...   2200               3
# 319  https://www.otodom.pl/pl/oferta/przytulne-mies...   2400               3
# 320  https://www.otodom.pl/pl/oferta/exclusive-apar...   2700               2
# 321  https://www.otodom.pl/pl/oferta/wynajem-kwiatk...   2700               2
# 322  https://www.otodom.pl/pl/oferta/wynajme-mieszk...   2500               2
# 323  https://www.otodom.pl/pl/oferta/apartament-do-...   3000               2
#
#      surface     rent  offer_type                 time
# 304     58.00   460.0         NaN  2024-08-31 21:56:20
# 305     56.00   800.0         NaN  2024-08-31 21:56:20
# 306     21.00   190.0         NaN  2024-08-31 21:56:21
# 307     44.00     NaN         NaN  2024-08-31 21:56:21
# 308     65.00   640.0         NaN  2024-08-31 21:56:21
# 309     38.39     NaN         NaN  2024-08-31 21:56:21
# 310     52.00   750.0         NaN  2024-08-31 21:56:22
# 311     44.00     NaN         NaN  2024-08-31 21:56:22
# 312     56.00   942.0         NaN  2024-08-31 21:56:22
# 313     62.00   750.0         NaN  2024-08-31 21:56:22
# 314     48.00   700.0         NaN  2024-08-31 21:56:23
# 315    110.00     NaN         NaN  2024-08-31 21:56:23
# 316     42.00   720.0         NaN  2024-08-31 21:56:23
# 317     17.17   400.0         NaN  2024-08-31 21:56:23
# 318     53.00   700.0         NaN  2024-08-31 21:56:24
# 319     70.00   800.0         NaN  2024-08-31 21:56:24
# 320     40.00  1000.0         NaN  2024-08-31 21:56:25
# 321     52.00   800.0         NaN  2024-08-31 21:56:25
# 322     49.00   700.0         NaN  2024-08-31 21:56:26
# 323     45.50   550.0         NaN  2024-08-31 21:56:26

# %%
# df['rent'] = df['rent'].str.replace(' ', '')
# df['rent'] = df['rent'].str.replace(',', '.')
df['rent'] = df['rent'].astype(float)
df['rent']
# Out:
# 0       720.0
# 1       225.0
# 2       422.0
# 3         NaN
# 4       450.0
#         ...
# 319     800.0
# 320    1000.0
# 321     800.0
# 322     700.0
# 323     550.0
# Name: rent, Length: 324, dtype: float64

# %%
df.to_csv(name_file)

# %%
df= pd.read_csv(name_file)
df
# Out:
#      Unnamed: 0   Nr                                              title  \
# 0             0    1      Dwupokojowe,54m2,Rzeszow,Kopernika,rej.Rynku,
# 1             1    2  Wyjatkowe mieszkanie 2 pok. SKYRES 16p. z wido...
# 2             2    3           Kawalerka z balkonem Rzeszow Architektow
# 3             3    4                  Wygodna kawalerka ul. Podwislocze
# 4             4    5          Mieszkanie 48 m2 z ogrodkiem bezposrednio
# ..          ...  ...                                                ...
# 319         319  320        Przytulne mieszkanie - Pobitno Rzeszow 70m2
# 320         320  321       EXCLUSIVE Apartament on KRAKOVSKA in Rzeszow
# 321         321  322         Wynajem, Kwiatkowskiego Tarasy nad Zalewem
# 322         322  323   wynajme mieszkanie Baranowka ladne/wysoka jakosc
# 323         323  324  Apartament do wynajecia przy zalewie w Rzeszowie!
#
#                         street          district     city   voivodeship  \
# 0           Mikolaja_Kopernika       Srodmiescie  Rzeszow  podkarpackie
# 1                     Lubelska        1000-Lecia  Rzeszow  podkarpackie
# 2                    Podgorska  Zawiszy_Czarnego  Rzeszow  podkarpackie
# 3                  Podwislocze       Nowe_Miasto  Rzeszow  podkarpackie
# 4      kard._Karola_Wojtyly_70       Srodmiescie  Rzeszow  podkarpackie
# ..                         ...               ...      ...           ...
# 319                 Kurpiowska           Pobitno  Rzeszow  podkarpackie
# 320               Krakowska_31      Przybyszowka  Rzeszow  podkarpackie
# 321  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
# 322        Wladyslawa_Raginisa         Baranowka  Rzeszow  podkarpackie
# 323  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
#
#                                                   link  price  number_of_room  \
# 0    https://www.otodom.pl/pl/oferta/dwupokojowe-54...   2400               2
# 1    https://www.otodom.pl/pl/oferta/wyjatkowe-mies...   2500               2
# 2    https://www.otodom.pl/pl/oferta/kawalerka-z-ba...   1600               1
# 3    https://www.otodom.pl/pl/oferta/wygodna-kawale...    800               1
# 4    https://www.otodom.pl/pl/oferta/mieszkanie-48-...   2500               2
# ..                                                 ...    ...             ...
# 319  https://www.otodom.pl/pl/oferta/przytulne-mies...   2400               3
# 320  https://www.otodom.pl/pl/oferta/exclusive-apar...   2700               2
# 321  https://www.otodom.pl/pl/oferta/wynajem-kwiatk...   2700               2
# 322  https://www.otodom.pl/pl/oferta/wynajme-mieszk...   2500               2
# 323  https://www.otodom.pl/pl/oferta/apartament-do-...   3000               2
#
#      surface     rent  offer_type                 time
# 0        54.0   720.0         NaN  2024-08-31 21:54:46
# 1        37.0   225.0         NaN  2024-08-31 21:54:47
# 2        23.0   422.0         NaN  2024-08-31 21:54:47
# 3        45.0     NaN         NaN  2024-08-31 21:54:47
# 4        48.0   450.0         NaN  2024-08-31 21:54:48
# ..        ...     ...         ...                  ...
# 319      70.0   800.0         NaN  2024-08-31 21:56:24
# 320      40.0  1000.0         NaN  2024-08-31 21:56:25
# 321      52.0   800.0         NaN  2024-08-31 21:56:25
# 322      49.0   700.0         NaN  2024-08-31 21:56:26
# 323      45.5   550.0         NaN  2024-08-31 21:56:26
#
# [324 rows x 14 columns]

# %%
# df['number_of_room'] = df['number_of_room'].str.replace(' pokoje', '')
# df['number_of_room'] = df['number_of_room'].str.replace(' pokój', '')
# df['number_of_room'] = df['number_of_room'].str.replace(' pokoi', '')
# df['number_of_room'] = df['number_of_room'].astype(int)
df
# Out:
#      Unnamed: 0   Nr                                              title  \
# 0             0    1      Dwupokojowe,54m2,Rzeszow,Kopernika,rej.Rynku,
# 1             1    2  Wyjatkowe mieszkanie 2 pok. SKYRES 16p. z wido...
# 2             2    3           Kawalerka z balkonem Rzeszow Architektow
# 3             3    4                  Wygodna kawalerka ul. Podwislocze
# 4             4    5          Mieszkanie 48 m2 z ogrodkiem bezposrednio
# ..          ...  ...                                                ...
# 319         319  320        Przytulne mieszkanie - Pobitno Rzeszow 70m2
# 320         320  321       EXCLUSIVE Apartament on KRAKOVSKA in Rzeszow
# 321         321  322         Wynajem, Kwiatkowskiego Tarasy nad Zalewem
# 322         322  323   wynajme mieszkanie Baranowka ladne/wysoka jakosc
# 323         323  324  Apartament do wynajecia przy zalewie w Rzeszowie!
#
#                         street          district     city   voivodeship  \
# 0           Mikolaja_Kopernika       Srodmiescie  Rzeszow  podkarpackie
# 1                     Lubelska        1000-Lecia  Rzeszow  podkarpackie
# 2                    Podgorska  Zawiszy_Czarnego  Rzeszow  podkarpackie
# 3                  Podwislocze       Nowe_Miasto  Rzeszow  podkarpackie
# 4      kard._Karola_Wojtyly_70       Srodmiescie  Rzeszow  podkarpackie
# ..                         ...               ...      ...           ...
# 319                 Kurpiowska           Pobitno  Rzeszow  podkarpackie
# 320               Krakowska_31      Przybyszowka  Rzeszow  podkarpackie
# 321  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
# 322        Wladyslawa_Raginisa         Baranowka  Rzeszow  podkarpackie
# 323  Eugeniusza_Kwiatkowskiego       Drabinianka  Rzeszow  podkarpackie
#
#                                                   link  price  number_of_room  \
# 0    https://www.otodom.pl/pl/oferta/dwupokojowe-54...   2400               2
# 1    https://www.otodom.pl/pl/oferta/wyjatkowe-mies...   2500               2
# 2    https://www.otodom.pl/pl/oferta/kawalerka-z-ba...   1600               1
# 3    https://www.otodom.pl/pl/oferta/wygodna-kawale...    800               1
# 4    https://www.otodom.pl/pl/oferta/mieszkanie-48-...   2500               2
# ..                                                 ...    ...             ...
# 319  https://www.otodom.pl/pl/oferta/przytulne-mies...   2400               3
# 320  https://www.otodom.pl/pl/oferta/exclusive-apar...   2700               2
# 321  https://www.otodom.pl/pl/oferta/wynajem-kwiatk...   2700               2
# 322  https://www.otodom.pl/pl/oferta/wynajme-mieszk...   2500               2
# 323  https://www.otodom.pl/pl/oferta/apartament-do-...   3000               2
#
#      surface     rent  offer_type                 time
# 0        54.0   720.0         NaN  2024-08-31 21:54:46
# 1        37.0   225.0         NaN  2024-08-31 21:54:47
# 2        23.0   422.0         NaN  2024-08-31 21:54:47
# 3        45.0     NaN         NaN  2024-08-31 21:54:47
# 4        48.0   450.0         NaN  2024-08-31 21:54:48
# ..        ...     ...         ...                  ...
# 319      70.0   800.0         NaN  2024-08-31 21:56:24
# 320      40.0  1000.0         NaN  2024-08-31 21:56:25
# 321      52.0   800.0         NaN  2024-08-31 21:56:25
# 322      49.0   700.0         NaN  2024-08-31 21:56:26
# 323      45.5   550.0         NaN  2024-08-31 21:56:26
#
# [324 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      324 non-null    int64
#  1   Nr              324 non-null    int64
#  2   title           324 non-null    object
#  3   street          241 non-null    object
#  4   district        324 non-null    object
#  5   city            324 non-null    object
#  6   voivodeship     324 non-null    object
#  7   link            324 non-null    object
#  8   price           324 non-null    int64
#  9   number_of_room  324 non-null    int64
#  10  surface         324 non-null    float64
#  11  rent            258 non-null    float64
#  12  offer_type      0 non-null      float64
#  13  time            324 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 35.6+ KB

# %%
df['district'] = df['district'].astype('category')
df['city'] = df['city'].astype('category')
df['voivodeship'] = df['voivodeship'].astype('category')
df['offer_type'] = df['offer_type'].astype('category')

# %%
df.to_csv(name_file)
